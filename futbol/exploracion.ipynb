# %%
import pandas as pd

# %%
a = pd.read_csv('FullData.csv')

# %%
a
# Out:
#                     Name          Nationality National_Position  National_Kit  \
# 0      Cristiano Ronaldo             Portugal                LS           7.0
# 1           Lionel Messi            Argentina                RW          10.0
# 2                 Neymar               Brazil                LW          10.0
# 3            Luis Suárez              Uruguay                LS           9.0
# 4           Manuel Neuer              Germany                GK           1.0
# ...                  ...                  ...               ...           ...
# 17583        Adam Dunbar  Republic of Ireland               NaN           NaN
# 17584       Dylan McGoey  Republic of Ireland               NaN           NaN
# 17585    Tommy Ouldridge              England               NaN           NaN
# 17586         Mark Foden             Scotland               NaN           NaN
# 17587   Barry Richardson              England               NaN           NaN
#
# ...

# %%
a.columns
# Out:
# Index(['Name', 'Nationality', 'National_Position', 'National_Kit', 'Club',
#        'Club_Position', 'Club_Kit', 'Club_Joining', 'Contract_Expiry',
#        'Rating', 'Height', 'Weight', 'Preffered_Foot', 'Birth_Date', 'Age',
#        'Preffered_Position', 'Work_Rate', 'Weak_foot', 'Skill_Moves',
#        'Ball_Control', 'Dribbling', 'Marking', 'Sliding_Tackle',
#        'Standing_Tackle', 'Aggression', 'Reactions', 'Attacking_Position',
#        'Interceptions', 'Vision', 'Composure', 'Crossing', 'Short_Pass',
#        'Long_Pass', 'Acceleration', 'Speed', 'Stamina', 'Strength', 'Balance',
#        'Agility', 'Jumping', 'Heading', 'Shot_Power', 'Finishing',
#        'Long_Shots', 'Curve', 'Freekick_Accuracy', 'Penalties', 'Volleys',
#        'GK_Positioning', 'GK_Diving', 'GK_Kicking', 'GK_Handling',
#        'GK_Reflexes'],
#       dtype='object')

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17588 entries, 0 to 17587
# Data columns (total 53 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                17588 non-null  object
#  1   Nationality         17588 non-null  object
#  2   National_Position   1075 non-null   object
#  3   National_Kit        1075 non-null   float64
#  4   Club                17588 non-null  object
#  5   Club_Position       17587 non-null  object
#  6   Club_Kit            17587 non-null  float64
#  7   Club_Joining        17587 non-null  object
#  8   Contract_Expiry     17587 non-null  float64
#  9   Rating              17588 non-null  int64
#  10  Height              17588 non-null  object
#  11  Weight              17588 non-null  object
#  12  Preffered_Foot      17588 non-null  object
#  13  Birth_Date          17588 non-null  object
#  14  Age                 17588 non-null  int64
# ...

# %%
a = a.drop(["National_Position", "National_Kit","Club_Kit", "Club_Joining", "Contract_Expiry"], axis = 1)

# %%
a.head()
# Out:
#                 Name Nationality          Club Club_Position  Rating  Height  \
# 0  Cristiano Ronaldo    Portugal   Real Madrid            LW      94  185 cm
# 1       Lionel Messi   Argentina  FC Barcelona            RW      93  170 cm
# 2             Neymar      Brazil  FC Barcelona            LW      92  174 cm
# 3        Luis Suárez     Uruguay  FC Barcelona            ST      92  182 cm
# 4       Manuel Neuer     Germany     FC Bayern            GK      92  193 cm
#
#   Weight Preffered_Foot  Birth_Date  Age  ... Long_Shots Curve  \
# 0  80 kg          Right  02/05/1985   32  ...         90    81
# 1  72 kg           Left  06/24/1987   29  ...         88    89
# 2  68 kg          Right  02/05/1992   25  ...         77    79
# 3  85 kg          Right  01/24/1987   30  ...         86    86
# 4  92 kg          Right  03/27/1986   31  ...         16    14
#
#    Freekick_Accuracy  Penalties  Volleys  GK_Positioning  GK_Diving  \
# ...

# %%
a['Weight'] = a['Weight'].apply(lambda x: int(x.split(' ')[0]))

# %%
a['Height'] = a['Height'].apply(lambda x: int(x.split(' ')[0]))

# %%
a.head()
# Out:
#                 Name Nationality          Club Club_Position  Rating  Height  \
# 0  Cristiano Ronaldo    Portugal   Real Madrid            LW      94     185
# 1       Lionel Messi   Argentina  FC Barcelona            RW      93     170
# 2             Neymar      Brazil  FC Barcelona            LW      92     174
# 3        Luis Suárez     Uruguay  FC Barcelona            ST      92     182
# 4       Manuel Neuer     Germany     FC Bayern            GK      92     193
#
#    Weight Preffered_Foot  Birth_Date  Age  ... Long_Shots Curve  \
# 0      80          Right  02/05/1985   32  ...         90    81
# 1      72           Left  06/24/1987   29  ...         88    89
# 2      68          Right  02/05/1992   25  ...         77    79
# 3      85          Right  01/24/1987   30  ...         86    86
# 4      92          Right  03/27/1986   31  ...         16    14
#
#    Freekick_Accuracy  Penalties  Volleys  GK_Positioning  GK_Diving  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
a.head()
# Out:
#                 Name Nationality          Club Club_Position  Rating  Height  \
# 0  Cristiano Ronaldo    Portugal   Real Madrid            LW      94     185
# 1       Lionel Messi   Argentina  FC Barcelona            RW      93     170
# 2             Neymar      Brazil  FC Barcelona            LW      92     174
# 3        Luis Suárez     Uruguay  FC Barcelona            ST      92     182
# 4       Manuel Neuer     Germany     FC Bayern            GK      92     193
#
#    Weight Preffered_Foot  Birth_Date  Age Preffered_Position        Work_Rate  \
# 0      80          Right  02/05/1985   32              LW/ST       High / Low
# 1      72           Left  06/24/1987   29                 RW  Medium / Medium
# 2      68          Right  02/05/1992   25                 LW    High / Medium
# 3      85          Right  01/24/1987   30                 ST    High / Medium
# 4      92          Right  03/27/1986   31                 GK  Medium / Medium
#
# ...

# %%
a.drop(index=a.index[50:], inplace=True)

# %%
a
# Out:
#                          Name     Nationality             Club Club_Position  \
# 0           Cristiano Ronaldo        Portugal      Real Madrid            LW
# 1                Lionel Messi       Argentina     FC Barcelona            RW
# 2                      Neymar          Brazil     FC Barcelona            LW
# 3                 Luis Suárez         Uruguay     FC Barcelona            ST
# 4                Manuel Neuer         Germany        FC Bayern            GK
# 5                      De Gea           Spain   Manchester Utd            GK
# 6          Robert Lewandowski          Poland        FC Bayern            ST
# 7                 Gareth Bale           Wales      Real Madrid            RW
# 8          Zlatan Ibrahimović          Sweden   Manchester Utd            ST
# 9            Thibaut Courtois         Belgium          Chelsea            GK
# 10             Jérôme Boateng         Germany        FC Bayern           Sub
# ...

# %%
a.to_csv('futbol_limpio.csv', index=False)
